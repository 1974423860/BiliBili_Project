# %%
import json
import pandas as pd
import numpy as np

# %%
# data = pd.read_json('bilibili.json',lines=True,encoding='gbk')
# data.to_excel('番剧排行榜.xlsx')

# %%
# data.to_excel('番剧排行榜.xlsx')

# %%
anime_data = pd.read_excel('番剧排行榜.xlsx')

# %%
anime_data.sum().isnull()
# Out:
# 排名      False
# 番剧名     False
# 评 分     False
# 弹幕量     False
# 收藏量     False
# 总观看数    False
# dtype: bool

# %%
anime_data.describe()
# Out:
#              排名        评 分           弹幕量           收藏量          总观看数
# count  50.00000  50.000000  5.000000e+01  5.000000e+01  5.000000e+01
# mean   25.50000   9.198000  7.777108e+06  4.195727e+06  1.898941e+08
# std    14.57738   1.132721  4.408849e+07  4.267707e+06  2.677463e+08
# min     1.00000   4.500000  4.750000e+02  3.296700e+04  6.161590e+05
# 25%    13.25000   9.200000  4.060175e+04  9.698655e+05  1.164231e+07
# 50%    25.50000   9.600000  2.935935e+05  2.409208e+06  5.834473e+07
# 75%    37.75000   9.700000  1.563432e+06  6.620860e+06  2.584480e+08
# max    50.00000   9.900000  3.126480e+08  1.555430e+07  1.009670e+09

# %%
anime_data
# Out:
#     排名                        番剧名  评 分        弹幕量       收藏量        总观看数
# 0    1                  鬼灭之刃 刀匠村篇  9.2     192477  15554304    80341153
# 1    2                  物理魔法使-马修-  8.6      97887   1060153    40379105
# 2    3                博人传 火影忍者新时代  4.5    4978632   2221453   352508557
# 3    4             超常技能开启奇幻世界美食之旅  9.6      61576    431342    21063675
# 4    5                       跃动青春  9.9     214488   1373471    44554424
# 5    6               命运-奇异赝品 黎明低语  9.5       5505    317536     3429880
# 6    7               总之就是非常可爱 第二季  9.4      74138   5476973     9735031
# 7    8                入间同学入魔了 第三季  9.4      48653   3865018    26861804
# 8    9                    假面骑士 极狐  9.6     119588    400688    34313898
# 9   10                       鬼灭之刃  9.7   10361404  12524274   970875004
# 10  11                    放学后失眠的你  9.5      60536    482341    10539169
# 11  12            齐木楠雄的灾难（日播&精选版）  9.7    1316854   1974764   254751145
# 12  13                   冰海战记 第二季  9.7       3118   1939461      915094
# 13  14           因为太怕痛就全点防御力了 第二季  9.3     296749   7002156   106242129
# 14  15                   鬼灭之刃 游郭篇  9.7     989473  14076388   261096173
# 15  16                      名侦探柯南  9.8  312648028   4636472   916857922
# 16  17                   久保同学不放过我  9.5     189439    945573    28832661
# 17  18         Ｄｒ．ＳＴＯＮＥ 石纪元 (第三季)  9.8     103703   4428791    37928257
# 18  19                       咒术回战  9.7    5135187  11916012   791662190
# 19  20                   祭品公主与兽之王  9.0      21767    328551     6350914
# 20  21              不知情的转学生硬要凑上来。  9.7       5158     54356      950931
# 21  22                   火影忍者 疾风传  9.6    2951302   2085667   204011787
# 22  23                 弦音 -连结的一射-  9.6       3187   1259271      616159
# 23  24                    雷古洛思奥特曼  8.3      37918    108001     5276790
# 24  25                      黑色四叶草  9.5    3117871   3078914   387857429
# 25  26                      孤独摇滚！  9.9     586574   2853116   105213272
# 26  27                      间谍过家家  9.7    3025401  12035886   715440158
# 27  28                小林家的龙女仆 第二季  9.6     604659   8653914   127035075
# 28  29                    齐木楠雄的灾难  9.7    1582395   3271854   175027184
# 29  30             攻壳机动队 2045 第二季  9.4       5060   1042743     1435839
# 30  31                  名侦探柯南（中配）  9.8   15806176   1807371  1009670410
# 31  32                 鬼灭之刃 无限列车篇  9.8     921703  13259026   189601991
# 32  33                       蓝色监狱  9.6     276021    877386    47944508
# 33  34             JOJO的奇妙冒险 黄金之风  9.8    4639272   5105960   527469088
# 34  35                 国王排名 勇气的宝箱  7.7      18718   8855671    21536149
# 35  36                齐木楠雄的灾难 第二季  9.8    1399617   2530936   146210274
# 36  37                    小林家的龙女仆  9.7    5802087   8193441   344577588
# 37  38                       堀与宫村  9.8    2617083   7649041   259680292
# 38  39                        星掠者  5.4    1102482   2696498   139404599
# 39  40          砂糖苹果童话故事 银砂糖师与黑妖精  8.9        475    146857      658463
# 40  41          关于我转生变成史莱姆这档事 第二季  8.9    2778924   9071353   422185585
# 41  42                  夏目友人帐 第六季  9.8    1274694   2287480    55598487
# 42  43               名侦探柯南：犯人犯泽先生  9.7      12727   4525786    11566966
# 43  44                      格莱普尼尔  8.9     441542   2009744    55562270
# 44  45                   见面5秒开始战斗  8.7     290438   1984813    61090969
# 45  46                       碧蓝之海  9.9    1091771   4901632   172582336
# 46  47  TRINITY SEVEN 七人魔法使 剧场版 2  9.1       7137    420301     5605945
# 47  48                假面骑士 极狐（中配）  9.2      11365     32967    11868347
# 48  49              JOJO的奇妙冒险 石之海  9.8    1506542   7897669   280589899
# 49  50               冰剑的魔术师将要统一世界  5.5      17874    132965     9199340

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Songti SC']
plt.rcParams['axes.unicode_minus'] = False

# %%
# 综合评分和播放量对比
# 综合评分条形图
#p = plt.figure(figsize=(16,16))
fig,ax1 = plt.subplots()
plt.bar(anime_data['番剧名'],anime_data['评 分'],color='cyan')
plt.title('综合评分和播放量数据分析')
#ax1.tick_params(labelsize=6)

plt.xlabel('番剧名')
plt.ylabel('综合评分')
plt.xticks(fontsize=6)
plt.xticks(rotation=90,color='green') # 设置横坐标变量名旋转度数和颜色

# 播放量折线图
ax2 = ax1.twinx() # 组合图
ax2.plot(anime_data['总观看数'],color='red')
plt.ylabel('播放量')
plt.plot(1, label='综合评分', color="cyan", linewidth=5.0)
plt.plot(1, label='播放量', color="red", linewidth=1.0, linestyle="-")
plt.legend()
plt.savefig(r'综合评分和播放量.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# 播放数和收藏数对比
# 播放数条形图
fig, ax3 = plt.subplots()
plt.bar(anime_data['番剧名'], anime_data['总观看数'], color='green')
plt.title('番剧总播放量和收藏数分析')
plt.ylabel('播放数（万）')
ax3.tick_params(labelsize=6)
plt.xticks(rotation=90, color='green')

# 收藏数折线图
ax4 = ax3.twinx()
ax4.plot(anime_data['收藏量'], color='orange')
plt.ylabel('收藏数（万）')

plt.plot(1, label='总观看数', color="green", linewidth=5.0)
plt.plot(1, label='收藏数', color="yellow", linewidth=1.0, linestyle="-")
plt.legend()
plt.savefig(r'番剧评论数和收藏数.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# 综合评分和收藏数对比
# 综合评分条形图
fig, ax5 = plt.subplots()
plt.bar(anime_data['番剧名'], anime_data['收藏量'], color='red')
plt.title('评分和收藏数量数据分析')
plt.ylabel('收藏数（万）')
ax5.tick_params(labelsize=6)
plt.xticks(rotation=90, color='green')

# 收藏折线图
ax6 = ax5.twinx() 
ax6.plot(anime_data['评 分'], color='yellow')  
plt.ylabel('评分')
plt.plot(1, label='收藏数', color="red", linewidth=5.0)
plt.plot(1, label='评分', color="yellow", linewidth=1.0, linestyle="-")
plt.legend()
plt.savefig(r'评分和收藏数.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
#弹幕量与播放量对比
fig,ax7 = plt.subplots()
plt.bar(anime_data['番剧名'],anime_data['总观看数'],color='orange')
plt.title('弹幕量和播放量数据分析')
plt.ylabel('播放量（万）')
ax7.tick_params(labelsize=6)
plt.xticks(rotation=90,color='green')

ax8 = ax7.twinx()
ax8.plot(anime_data['弹幕量'],color='black')
plt.ylabel('弹幕量')
plt.plot(1, label='播放量', color="orange", linewidth=5.0)
plt.plot(1, label='弹幕量', color="black", linewidth=1.0, linestyle="-")
plt.legend()
plt.savefig(r'弹幕量和播放量.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
p = plt.figure(figsize=(8,10))

ax1 = p.add_subplot(2,2,1)
plt.scatter(anime_data['总观看数'],anime_data['收藏量'],color='b')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('播放数（万）')
plt.ylabel('收藏数（万）')

ax2 = p.add_subplot(2,2,2)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.scatter(anime_data['排名'],anime_data['收藏量'],color='r')
plt.xlabel('排名')
plt.ylabel('收藏数（万）')
#fig.tight_layout()
plt.subplots_adjust(wspace =0.45, hspace =0.4)
plt.show()

# %%
############评分密度直方图############
import seaborn as sns
plt.figure(figsize=(6,6))
plt.suptitle('评分密度直方图',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel("评分密度",fontsize=20)
plt.ylabel(" ",fontsize=20)
sns.distplot(anime_data["评 分"])
plt.grid()
plt.show()
# Out:
# /Applications/python/Anacond/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 设置字体
pf = [0, 0, 0, 0, 0, 0, 0] #用来记录特定条件出现的次数
#开始逐个分析评分
for i in range(len(anime_data['评 分'])):
    if anime_data['评 分'][i] > 9.5:
        pf[0] = pf[0] + 1
    if anime_data['评 分'][i] > 9.0 and anime_data['评 分'][i] <= 9.5:
        pf[1] = pf[1] + 1
    if anime_data['评 分'][i] > 8.5 and anime_data['评 分'][i] <= 9.0:
        pf[2] = pf[2] + 1
    if anime_data['评 分'][i] > 8.0 and anime_data['评 分'][i] <= 8.5:
        pf[3] = pf[3] + 1
    if anime_data['评 分'][i] > 7.5 and anime_data['评 分'][i] <= 8.0:
        pf[4] = pf[4] + 1
    if anime_data['评 分'][i] > 7.0 and anime_data['评 分'][i] <= 7.5:
        pf[5] = pf[5] + 1
    if anime_data['评 分'][i] <= 7.0:
        pf[6] = pf[6] + 1

label = '>9.5', '9.0-9.5', '8.5-9.0', '8.0-8.5', '7.5-8.0', '7.0-7.5', '<7.0'#标题
color = 'red', 'orange', 'yellow', 'pink', 'green', 'blue'  #颜色
cs = [0, 0, 0, 0, 0, 0, 0]
#用来显示百分比占比
explode = [0, 0, 0, 0, 0, 0, 0]
#每块离中心的距离；
for i in range(0,7):  # 计算
    #print(i)
    cs[i] = pf[i] * 2
    explode[i] = pf[i] / 500

#开始配置图形
pie = plt.pie(cs, colors=color, explode=explode, labels=label, shadow=True, autopct='%1.1f%%')
for font in pie[1]:
    font.set_size(12)
for digit in pie[2]:
    digit.set_size(8)
plt.axis('equal')
#配置标题，字号大小等：
plt.title(u'各个评分占比', fontsize=18)
plt.legend(loc=0, bbox_to_anchor=(0.8, 1))
leg = plt.gca().get_legend()
ltext = leg.get_texts()
plt.setp(ltext, fontsize=8)
#显示视图
plt.show()

# %%
list(pf)
# Out:
# [28, 11, 6, 1, 1, 0, 3]

# %%
list(label)
# Out:
# ['>9.5', '9.0-9.5', '8.5-9.0', '8.0-8.5', '7.5-8.0', '7.0-7.5', '<7.0']

# %%
# label = list(map(str,anime_data['番剧名']))
# x = list(map(int,anime_data['总观看数']))
data=[[label[i],pf[i]] for i in range(len(label))]

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel
funnel = (Funnel().add('',data_pair=data,label_opts=opts.LabelOpts(
          position='inside',formatter='{b}:{d}%'),gap=2,
          tooltip_opts=opts.TooltipOpts(trigger='item'),
          itemstyle_opts=opts.ItemStyleOpts(border_color='#fff',border_width=1))
          .set_global_opts(title_opts=opts.TitleOpts(title='各评分占比'))
         )


#funnel.render_notebook()
funnel.render("番剧各评分占比.html")
# Out:
# '/Users/ciao/Desktop/BiliBili_Project/数据分析/番剧各评分占比.html'

# %%
import jieba
import wordcloud
from PIL import Image
content_list = [i for i in anime_data['番剧名']]
content = ' '.join(content_list)
txt = jieba.lcut(content)
string = ' '.join(txt)
backgroud = np.array(Image.open('小电视.jpeg'))
bili_cloud = wordcloud.WordCloud(mask = backgroud,
                                 background_color='white',
                                 font_path = 'Library/Fonts/Songti.ttc',
                                 stopwords={'第二季'},
                                 scale=10
                                )
bili_cloud.generate(string)
bili_cloud.to_file('番剧词云图.png')
